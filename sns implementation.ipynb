# %%
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
#load dataset
df_udemycourse=pd.read_csv('udemy_courses.csv')
iris = sns.load_dataset('iris')

#display dataframe without truncation
pd.set_option('display.max_column', None)
pd.set_option('display.expand_frame_repr', False)

# %%
#print iris dataset 
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
#print udemy_courses dataset
df_udemycourse.head()
# Out:
#    course_id                                       course_title                                                url  is_paid  price  num_subscribers  num_reviews  num_lectures               level  content_duration   published_timestamp           subject
# 0    1070968                 Ultimate Investment Banking Course  https://www.udemy.com/ultimate-investment-bank...     True    200             2147           23            51          All Levels               1.5  2017-01-18T20:58:58Z  Business Finance
# 1    1113822  Complete GST Course & Certification - Grow You...      https://www.udemy.com/goods-and-services-tax/     True     75             2792          923           274          All Levels              39.0  2017-03-09T16:34:20Z  Business Finance
# ...

# %%
iris.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
iris.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
iris.shape[0]
# Out:
# 150

# %% [markdown]
# ### Select the column `is_paid` and plot a bar chart
# sns.countplot("col1", data = df)

# %%
# example
sns.countplot(x="species", data=iris)
# Out:
# <AxesSubplot: xlabel='species', ylabel='count'>

# %%
#countplot is_paid
sns.countplot(x="is_paid", data=df_udemycourse)
# Out:
# <AxesSubplot: xlabel='is_paid', ylabel='count'>

# %% [markdown]
# ### Use the column **subject** as x-axis and the column **price** as y-axis to plot the bar plot
# sns.barplot(data=df, x="col1", y="col2",  estimator = np.median)

# %%
# example
plt.figure(figsize=(8,5))
sns.barplot(data=iris, x="species", y="sepal_length", estimator = np.median)
# Out:
# <AxesSubplot: xlabel='species', ylabel='sepal_length'>

# %%
# barplot price column
plt.figure(figsize=(8,5))
sns.barplot(data=df_udemycourse, x="subject", y="price", estimator = np.median)
# Out:
# <AxesSubplot: xlabel='subject', ylabel='price'>

# %% [markdown]
# ### Visualize the distributions  of   **num_subscribers** and **num_reviews** with **subject**
# sns.jointplot(data=df, x="col1", y="col2", hue="subject")

# %%
# exmaple 
sns.jointplot(data=iris, x="sepal_length", y="sepal_width", hue="species")

# %%
#show data distribution 
sns.jointplot(data=df_udemycourse, x="num_subscribers", y="num_reviews", hue="subject")

# %% [markdown]
# ### Select the following column to plot the seaborn pairplot
# - price
# - num_subscribers
# - num_reviews
# - num_lectures
# - content_duration
# - subject
#
# hue use **subject**
#
# sns.pairplot(data=df, hue="subject")

# %%
# example
sns.pairplot(data=iris[['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']], hue="species")

# %%
#show pairplot of all features in df_udemycourse dataset
sns.pairplot(data=df_udemycourse[['price', 'num_subscribers', 'num_reviews', 'num_lectures', 'content_duration', 'subject']], hue="subject")
